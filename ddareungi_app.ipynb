# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sb

# %%
train=pd.read_csv('Documents/YH_python/data/train.csv')
test=pd.read_csv('Documents/YH_python/data/test.csv')

# %%
train.shape
# Out:
# (1459, 11)

# %%
train.describe()
# Out:
#                 id         hour  hour_bef_temperature  hour_bef_precipitation  \
# count  1459.000000  1459.000000           1457.000000             1457.000000
# mean   1105.914325    11.493489             16.717433                0.031572
# std     631.338681     6.922790              5.239150                0.174917
# min       3.000000     0.000000              3.100000                0.000000
# 25%     555.500000     5.500000             12.800000                0.000000
# 50%    1115.000000    11.000000             16.600000                0.000000
# 75%    1651.000000    17.500000             20.100000                0.000000
# max    2179.000000    23.000000             30.000000                1.000000
#
#        hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# count         1450.000000        1457.000000          1457.000000
# mean             2.479034          52.231297          1405.216884
# std              1.378265          20.370387           583.131708
# ...

# %%
train.isna().sum()
# Out:
# id                          0
# hour                        0
# hour_bef_temperature        2
# hour_bef_precipitation      2
# hour_bef_windspeed          9
# hour_bef_humidity           2
# hour_bef_visibility         2
# hour_bef_ozone             76
# hour_bef_pm10              90
# hour_bef_pm2.5            117
# count                       0
# dtype: int64

# %%
test.isna().sum()
# Out:
# id                         0
# hour                       0
# hour_bef_temperature       1
# hour_bef_precipitation     1
# hour_bef_windspeed         1
# hour_bef_humidity          1
# hour_bef_visibility        1
# hour_bef_ozone            35
# hour_bef_pm10             37
# hour_bef_pm2.5            36
# dtype: int64

# %%
# 결측치 제거
train=train.dropna()

# %%
train
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 0        3    20                  16.3                     1.0
# 1        6    13                  20.1                     0.0
# 2        7     6                  13.9                     0.0
# 3        8    23                   8.1                     0.0
# 4        9    18                  29.5                     0.0
# ...    ...   ...                   ...                     ...
# 1454  2174     4                  16.8                     0.0
# 1455  2175     3                  10.8                     0.0
# 1456  2176     5                  18.3                     0.0
# 1457  2178    21                  20.7                     0.0
# 1458  2179    17                  21.1                     0.0
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 0                    1.5               89.0                576.0
# 1                    1.4               48.0                916.0
# ...

# %%
train.head()
# Out:
#    id  hour  hour_bef_temperature  hour_bef_precipitation  hour_bef_windspeed  \
# 0   3    20                  16.3                     1.0                 1.5
# 1   6    13                  20.1                     0.0                 1.4
# 2   7     6                  13.9                     0.0                 0.7
# 3   8    23                   8.1                     0.0                 2.7
# 4   9    18                  29.5                     0.0                 4.8
#
#    hour_bef_humidity  hour_bef_visibility  hour_bef_ozone  hour_bef_pm10  \
# 0               89.0                576.0           0.027           76.0
# 1               48.0                916.0           0.042           73.0
# 2               79.0               1382.0           0.033           32.0
# 3               54.0                946.0           0.040           75.0
# 4                7.0               2000.0           0.057           27.0
#
#    hour_bef_pm2.5  count
# 0            33.0   49.0
# ...

# %%
test=test.dropna()

# %%
test
# Out:
#        id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 0       0     7                  20.7                     0.0
# 1       1    17                  30.0                     0.0
# 2       2    13                  19.0                     1.0
# 3       4     6                  22.5                     0.0
# 4       5    22                  14.6                     1.0
# ..    ...   ...                   ...                     ...
# 708  2146     3                  21.6                     0.0
# 709  2147    18                  24.3                     0.0
# 712  2165     9                  23.3                     0.0
# 713  2166    16                  27.0                     0.0
# 714  2177     8                  22.3                     0.0
#
#      hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 0                   1.3               62.0                954.0
# 1                   5.4               33.0               1590.0
# ...

# %%
# 시간대 별로 평균 몇개가 대여 되었는지 확인.
train.groupby(['hour'])['count'].mean()
# Out:
# hour
# 0      73.017544
# 2      31.644068
# 3      21.677966
# 4      13.483333
# 5      13.288136
# 6      24.413793
# 7      61.135593
# 8     138.254237
# 9      93.666667
# 10     79.655172
# 11     89.275862
# 12    111.732143
# 13    118.363636
# 14    133.517241
# 15    154.578947
# 16    175.094340
# 17    189.462963
# 18    264.314815
# 19    200.203390
# 20    164.982759
# 21    169.525424
# 22    148.333333
# 23    106.118644
# Name: count, dtype: float64

# %%
# 위에서 구한 시간대 별 대여갯수에 대한 시각화
train.groupby(['hour'])['count'].mean().plot()
plt.axvline(x=8,color='r')
plt.axvline(x=18,color='r')
plt.text(6, 150, 'go work')
plt.text(16, 150, 'leave work')
plt.show()

# %%
sb.violinplot(x = 'count', y = 'hour_bef_humidity', data = train)
# Out:
# <AxesSubplot:xlabel='count', ylabel='hour_bef_humidity'>

# %%
train.head(2)
# Out:
#    id  hour  hour_bef_temperature  hour_bef_precipitation  hour_bef_windspeed  \
# 0   3    20                  16.3                     1.0                 1.5
# 1   6    13                  20.1                     0.0                 1.4
#
#    hour_bef_humidity  hour_bef_visibility  hour_bef_ozone  hour_bef_pm10  \
# 0               89.0                576.0           0.027           76.0
# 1               48.0                916.0           0.042           73.0
#
#    hour_bef_pm2.5  count
# 0            33.0   49.0
# 1            40.0  159.0

# %%
# 상관 계수
plt.figure(figsize = (12, 12))
sb.heatmap(train.corr(), annot = True)
plt.show()

# %%
train.head()
# Out:
#    id  hour  hour_bef_temperature  hour_bef_precipitation  hour_bef_windspeed  \
# 0   3    20                  16.3                     1.0                 1.5
# 1   6    13                  20.1                     0.0                 1.4
# 2   7     6                  13.9                     0.0                 0.7
# 3   8    23                   8.1                     0.0                 2.7
# 4   9    18                  29.5                     0.0                 4.8
#
#    hour_bef_humidity  hour_bef_visibility  hour_bef_ozone  hour_bef_pm10  \
# 0               89.0                576.0           0.027           76.0
# 1               48.0                916.0           0.042           73.0
# 2               79.0               1382.0           0.033           32.0
# 3               54.0                946.0           0.040           75.0
# 4                7.0               2000.0           0.057           27.0
#
#    hour_bef_pm2.5  count
# 0            33.0   49.0
# ...

# %%
X=train.iloc[:,[2,3,4]]

# %%
y=train['count']

# %%
from sklearn.model_selection import train_test_split

# %%
# Training / Test 셋으로 분리
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=19)

# %%
from sklearn.linear_model import LinearRegression

# %%
# 모델링 과정
regressor=LinearRegression()

# %%
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
regressor.coef_
# Out:
# array([  8.27493136, -57.91853388,  16.90441554])

# %%
regressor.intercept_
# Out:
# -67.38770039812975

# %%
y_pred=regressor.predict(X_test)

# %%
y_pred
# Out:
# array([142.55878118,  87.81443472,  98.67821134, 182.53866034,
#         32.51421573,  14.77627104, 112.44993074,  71.12275087,
#        195.15176742,  89.22123402,  52.84699131,  73.48684278,
#         66.58325544, 109.3111986 ,  71.69003538,  25.68153895,
#         87.02239687, 173.93260979, 160.86999602,  70.29525774,
#        190.91995755,  43.23617122, 166.63901435,  58.27286879,
#        133.96475228,  49.85611631,  71.6545801 , 239.34002283,
#         30.39831079, 166.20152931, 105.68816453,   9.41531848,
#         28.30583948, 118.34874854, 103.66660378,  75.82750106,
#        153.10346026,  63.71076793, 125.35870173, 127.39228413,
#         47.62182387,  94.1387159 ,  48.41386172,  86.97491993,
#        198.33194049, 107.74518055, 115.10968656,  70.31869136,
#        173.79078866,  93.46506555,  76.51317307,  60.47170595,
#         19.02010257, 139.96993593,  75.26021655, 223.58219796,
#        110.97222088,  73.46340915, 138.78788997, 219.81130675,
# ...

# %%
error = y_test - y_pred

# %%
error ** 2
# Out:
# 1067      274.193234
# 1348     3821.024340
# 1454     6033.904517
# 65       2073.769586
# 792       755.468337
#             ...
# 296      1931.877450
# 1416      467.996076
# 568     14025.325862
# 143        57.053580
# 184       975.698392
# Name: count, Length: 266, dtype: float64

# %%
( error ** 2 ).mean()
# Out:
# 3605.6958876099934

# %%
plt.plot(y_test.values)
plt.plot(y_pred)
plt.legend(['Real','Pred'])
plt.show()

# %%
import joblib

# %%
joblib.dump(regressor,'regressor.pkl')
# Out:
# ['regressor.pkl']

# %%
# 기온 , 비가 오는가 안 오는가 , 풍속을 입력받아
# 따릉이 대여수를 예측

# %%
new_data = np.array([15,0,15])

# %%
new_data=new_data.reshape(1,3)

# %%
y_pred2 = regressor.predict(new_data)
# Out:
# C:\Users\5-5\Anaconda3\envs\YH\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
y_pred2
# Out:
# array([310.30250313])
